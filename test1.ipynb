# %% [markdown]
# <a href="https://colab.research.google.com/github/danmichaelo/google-colab-test/blob/master/test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import lxml

# %%
import xmltodict

# %%
import xml

# %%
# !pip install -q xmltodict

# %%
response = requests.get('http://www.cristin.no')

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="no">
#   <head>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#
#     <meta id="viewport" name="viewport" content="width=device-width, initial-scale=1" />
#
#
#    <meta charset="utf-8" >
#
#
#    <meta name="format-detection" content="telephone=no">
#    <meta name="generator" content="Vortex" />
#
#
#
#
#        <title>
#       Forsiden - Cristin</title>
#        <meta property="og:title" content="
#       Forsiden - Cristin" />
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <meta name="twitter:card" content="summary" />
#     <meta name="twitter:site" content="@unit" />
#     <meta name="twitter:title" content="Forsiden" />
#
#
#       <meta name="twitter:description" content="Les denne saken på cristin.no" />
#
#
#
#
#
#
#       <meta name="twitter:url" content="https://www.cristin.no/index.html" />
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <meta property="og:url" content="https://www.cristin.no/index.html" />
# ...

# %%
import requests
